# %% [markdown]
# <a href="https://colab.research.google.com/github/darshank26/50_ML_codes/blob/main/Example_04/ML_Prediction_for_give_texture_and_weight_is_of_orange_or_apple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import the list of lib needed
import sklearn
from sklearn import tree

# %%
features = [[155, 0], [180, 0],[135, 1],[110, 1]]
labels = ["orange", "orange", "apple", "apple"]

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(features, labels)

# %%
print (clf.predict(X = [[180, 2]]))
# Out:
# ['apple']

# %%
fig = plt.figure(figsize=(15,10))
_ = tree.plot_tree(clf, filled=True)
